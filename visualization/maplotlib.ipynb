# %% [markdown]
# # matpltlib
# ## world-developement-dataset
#
# * first download world-developement-dataset from kaggle

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
# !ls ./wdi
# Out:
# Country.csv	  database.sqlite  hashes.txt	   Series.csv
# CountryNotes.csv  Footnotes.csv    Indicators.csv  SeriesNotes.csv

# %%
# we will be using Indicators.csv
indi = pd.read_csv('./wdi/Indicators.csv')
print(indi.shape)
indi.head()                       # default is for first five location
# Out:
# (5656458, 6)
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
# optput for specific location
indi.iloc[[2,3,6,8,435]]
# Out:
#                                CountryName CountryCode  \
# 2                               Arab World         ARB
# 3                               Arab World         ARB
# 6                               Arab World         ARB
# 8                               Arab World         ARB
# 435  East Asia & Pacific (developing only)         EAP
#
#                                          IndicatorName   IndicatorCode  Year  \
# 2    Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL  1960
# 3    Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG  1960
# 6                 Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  1960
# 8               CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1960
# 435  Net bilateral aid flows from DAC donors, Denma...  DC.DAC.DNKL.CD  1960
#
#          Value
# 2     6.634579
# 3    81.023330
# 6    47.697888
# 8     0.643964
# 435   0.000000

# %% [markdown]
# ### Total number of countries that are in data set

# %%
# print(type(indi['CountryName']))
# print(indi['CountryName'])

# %%
# # all different element
# print(len(indi['CountryName'].unique()))
# # print(len(indi['CountryCode].unique()))
# print(type(indi['CountryName'].unique()))
# print(indi['CountryName'].unique())

# %%
# convert ndarray to list
x=indi['CountryName'].unique().tolist()
print(type(x))
x
# Out:
# <class 'list'>
# ['Arab World',
#  'Caribbean small states',
#  'Central Europe and the Baltics',
#  'East Asia & Pacific (all income levels)',
#  'East Asia & Pacific (developing only)',
#  'Euro area',
#  'Europe & Central Asia (all income levels)',
#  'Europe & Central Asia (developing only)',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: nonOECD',
#  'High income: OECD',
#  'Latin America & Caribbean (all income levels)',
#  'Latin America & Caribbean (developing only)',
#  'Least developed countries: UN classification',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Middle East & North Africa (all income levels)',
#  'Middle East & North Africa (developing only)',
#  'Middle income',
#  'North America',
#  'OECD members',
#  'Other small states',
#  'Pacific island small states',
#  'Small states',
#  'South Asia',
# ...

# %%
years = indi['Year'].unique()
print(years,type(years))
print(min(years),"--->",max(years))
len(years)
# Out:
# [1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974
#  1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015] <class 'numpy.ndarray'>
# 1960 ---> 2015
# 56

# %% [markdown]
# ## Co2 emmision for a specific country(India)
# * extracting india data from given csv files

# %%
import matplotlib.pyplot as plt 
import pandas as pd

indi = pd.read_csv('./wdi/Indicators.csv')

# %%
dummy_2 = indi['IndicatorName'].str.contains('CO2 emissions \(metric')
dummy = indi['CountryCode'].str.contains('India')
var = indi[dummy & dummy_2]
var.head()
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, IndicatorName, IndicatorCode, Year, Value]
# Index: []
